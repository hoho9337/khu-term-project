# %% [markdown]
# # Term Project
#
# by Hogeon Kim

# %%
# conda install watermark -c conda-forge

# %%
# %load_ext watermark
# %watermark -v -a "Hogeon Kim" -e "hoho9337@khu.ac.kr" -gu "hoho9337" -p numpy,matplotlib,pandas
# Out:
# Author: Hogeon Kim
#
# Github username: hoho9337
#
# Email: hoho9337@khu.ac.kr
#
# Python implementation: CPython
# Python version       : 3.9.12
# IPython version      : 8.2.0
#
# numpy     : 1.21.5
# matplotlib: 3.5.1
# pandas    : 1.4.2

# %% [markdown]
# ## 목차
# 1. 주제 선정 이유: 왜 이 주제(정보, 데이터)를 선정하게 된 이유를 나열
# 1. 가설 정의: 본인이 텀 프로젝트를 통해서 증명하고자 하는 명제 혹은 밝히고자 하는 논리가 무엇인지 설명
# 1. 인터넷을 통한 데이터 획득: 위의 명제/논리을 펼치기 위하여, 파이썬으로 어떤 데이터를 어떻게 획득했는지 구체적으로 설명
# 1. 분석을 위한 데이터의 가공: 데이터는 가공되지 않으면 의미가 없으므로, 어떤 데이터를 어떻게 가공했는지 설명
# 1. 분석 결과: 수학적 방법 혹은 논리적 방법을 파이썬으로 구현하여 분석 결과를 도출 (그래프 등의 가시화 활용)
# 1. 결론: 본인의 명제 혹은 밝히고자 하는 논리가 증명/확인 되었는지 구체적으로 서술
# 1. 참고문헌: 위의 작업을 위하여 참고한 자료, 인터넷 정보, 논문, 도서 등을 나열
# 1. 별첨: (3)의 획득한 데이터 원본
# 1. 별첨: (4)의 가공된 데이터 원본
# 1. 별첨: (3) 데이터 획득, (4) 데이터 가공, (5) 분석 결과를 도출하기까지 본인이 직접 작성한 파이썬 소스 코드 원본

# %% [markdown]
# # Proposal

# %% [markdown]
# ## 주제 : COVID-19의 치사율에 영향을 주는 요인 분석
#
#
# - 주제 선정 이유
# 1. 건강과 healthcare 관련된 관심도가 급격하게 증가하는 추세이다.
# 1. 여러 종류의 데이터 중 정보의 양과 신뢰도가 높다고 판단되었다.
# 1. 코로나-19 이후에 등장할 전염병에도 적용될 수 있는 내용이다.
# 1. 전염병과 관련된 강의와 도서를 접하게 되어 개인적 관심이 높아졌다.

# %% [markdown]
# ## 가설 / 명제
#
# - 1인당 담배 소비량이 높은 나라는 코로나-19 확진률도 높을 것이다.
# - 개인 건강/면역 상태(ex. 영양부족, Healthy life expectancy 등)가 불량할수록 코로나-19에 취약할 가능성이 높을 것이다.
# - 의료 종사자 수 비율이 높은 나라일수록 코로나-19로 인한 사망자가 적을 것이다.
# - 코로나-19로 인한 치사율이 높은 나라는 낮은 나라보다 다른 질병으로부터 더 취약할 것이다.
# - 코로나-19 백신 접종률이 높은 나라일수록 코로나-19 확진자 증가율이 적을 것이다.

# %% [markdown]
# ## 분석할 데이터의 출처와 데이터 내용
#
# - https://covid19.who.int :
#     국가별 코로나-19 확진자/사망자 추세
#
# - https://kosis.kr :
#     국가별 전염병 발생 추이, 영양부족 인구비율, 우리나라 개인 건강 상태, 국가별 흡연율/알코올 소비량,
#
# - https://www.who.int :
#    코로나-19 외 다른 질병의 국가별 통계자료

# %% [markdown]
# ## 분석 계획
#
# 1. 데이터 수집
#     - 국가별 코로나-19 확진자/사망자 추세
#     - 국가별 백신 접종 현황
#     - 국가별 개인 건강상태
#     - 국가별 의료 종사자 비율
#     - 국가별 1인당 담배 소비량
#     - 국가별 알코올 소비량
#     - 코로나-19 외 다른 질병의 국가별 통계자료
#
# 1. 개인 건강/위생/면역 상태를 대표할 수 있는 `feature` 선정
# 1. 필요한 데이터의 종류와 형태로 preprocess
# 1. 대표 `feature`들(개인 건강/위생/면역 상태, 백신접종률)과 코로나-19 발생/치사율 사이의 연관성 가시화
# 1. 그래프 분석 및 결론 도출

# %% [markdown]
# ### Raw Data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - 국가별 코로나-19 확진자/사망자 추세 : 대표 `feature`들과 연관시킬 key data

# %%
df_cov = pd.read_csv("data/WHO-COVID-19-global-table-data.csv")
df_cov
# Out:
#                                                   Name  WHO Region  \
# Global                                             NaN   626337158
# United States of America                      Americas    95946824
# India                                  South-East Asia    44649088
# France                                          Europe    35697506
# Germany                                         Europe    35523412
# ...                                                ...         ...
# Tuvalu                                 Western Pacific          23
# Pitcairn Islands                       Western Pacific           4
# Democratic People's Republic of Korea  South-East Asia           0
# Tokelau                                Western Pacific           0
# Turkmenistan                                    Europe           0
#
#                                        Cases - cumulative total  \
# Global                                              8035.588106
# United States of America                           28986.724000
# India                                               3235.431000
# France                                             54886.005000
# Germany                                            42713.499000
# ...                                                         ...
# Tuvalu                                               195.047000
# Pitcairn Islands                                    8000.000000
# Democratic People's Republic of Korea                  0.000000
# Tokelau                                                0.000000
# Turkmenistan                                           0.000000
#
#                                        Cases - cumulative total per 100000 population  \
# Global                                                                        2047229
# United States of America                                                            0
# India                                                                           10452
# France                                                                         267748
# Germany                                                                        386677
# ...                                                                               ...
# Tuvalu                                                                              0
# Pitcairn Islands                                                                    0
# Democratic People's Republic of Korea                                               0
# Tokelau                                                                             0
# Turkmenistan                                                                        0
#
#                                        Cases - newly reported in last 7 days  \
# Global                                                              26.26491
# United States of America                                             0.00000
# India                                                                0.75700
# France                                                             411.67100
# Germany                                                            464.94200
# ...                                                                      ...
# Tuvalu                                                               0.00000
# Pitcairn Islands                                                     0.00000
# Democratic People's Republic of Korea                                0.00000
# Tokelau                                                              0.00000
# Turkmenistan                                                         0.00000
#
#                                        Cases - newly reported in last 7 days per 100000 population  \
# Global                                                                            162207
# United States of America                                                               0
# India                                                                               2208
# France                                                                             37089
# Germany                                                                            41338
# ...                                                                                  ...
# Tuvalu                                                                                 0
# Pitcairn Islands                                                                       0
# Democratic People's Republic of Korea                                                  0
# Tokelau                                                                                0
# Turkmenistan                                                                           0
#
#                                        Cases - newly reported in last 24 hours  \
# Global                                                                 6566610
# United States of America                                               1059255
# India                                                                   528999
# France                                                                  153182
# Germany                                                                 153377
# ...                                                                        ...
# Tuvalu                                                                       0
# Pitcairn Islands                                                             0
# Democratic People's Republic of Korea                                        0
# Tokelau                                                                      0
# Turkmenistan                                                                 0
#
#                                        Deaths - cumulative total  \
# Global                                                 84.246276
# United States of America                              320.014000
# India                                                  38.333000
# France                                                235.522000
# Germany                                               184.421000
# ...                                                          ...
# Tuvalu                                                  0.000000
# Pitcairn Islands                                        0.000000
# Democratic People's Republic of Korea                   0.000000
# Tokelau                                                 0.000000
# Turkmenistan                                            0.000000
#
#                                        Deaths - cumulative total per 100000 population  \
# Global                                                                            5879
# United States of America                                                             0
# India                                                                               46
# France                                                                             513
# Germany                                                                            140
# ...                                                                                ...
# Tuvalu                                                                               0
# Pitcairn Islands                                                                     0
# Democratic People's Republic of Korea                                                0
# Tokelau                                                                              0
# Turkmenistan                                                                         0
#
#                                        Deaths - newly reported in last 7 days  \
# Global                                                               0.075425
# United States of America                                             0.000000
# India                                                                0.003000
# France                                                               0.789000
# Germany                                                              0.168000
# ...                                                                       ...
# Tuvalu                                                               0.000000
# Pitcairn Islands                                                     0.000000
# Democratic People's Republic of Korea                                0.000000
# Tokelau                                                              0.000000
# Turkmenistan                                                         0.000000
#
#                                        Deaths - newly reported in last 7 days per 100000 population  \
# Global                                                                               603
# United States of America                                                               0
# India                                                                                 12
# France                                                                                71
# Germany                                                                               11
# ...                                                                                  ...
# Tuvalu                                                                                 0
# Pitcairn Islands                                                                       0
# Democratic People's Republic of Korea                                                  0
# Tokelau                                                                                0
# Turkmenistan                                                                           0
#
#                                        Deaths - newly reported in last 24 hours
# Global                                                                      NaN
# United States of America                                                    NaN
# India                                                                       NaN
# France                                                                      NaN
# Germany                                                                     NaN
# ...                                                                         ...
# Tuvalu                                                                      NaN
# Pitcairn Islands                                                            NaN
# Democratic People's Republic of Korea                                       NaN
# Tokelau                                                                     NaN
# Turkmenistan                                                                NaN
#
# [238 rows x 12 columns]

# %% [markdown]
# - 국가별 백신 접종 현황

# %%
df_vac = pd.read_csv('data/vaccination-data.csv')
df_vac
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2022-10-24
# 1              Albania  ALB       EURO   REPORTING   2022-10-16
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2022-08-23
# 4              Andorra  AND       EURO   REPORTING   2022-10-16
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2022-10-13
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2022-07-26
# 226              Yemen  YEM       EMRO   REPORTING   2022-10-20
# 227             Zambia  ZMB       AFRO   REPORTING   2022-10-16
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2022-10-16
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            12055358.0                     11084618.0
# 1             2991576.0                      1339100.0
# 2            15267442.0                      7840131.0
# 3              111316.0                        44885.0
# 4              154320.0                        57898.0
# ..                  ...                            ...
# 224         260375471.0                     90028108.0
# 225             16782.0                         6592.0
# 226           1139242.0                       914722.0
# 227           9315275.0                      8556919.0
# 228          12622764.0                      6542794.0
#
#      TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                       30.968                                28.474
# 1                      104.000                                47.053
# 2                       34.817                                17.879
# 3                      201.670                                81.318
# 4                      199.700                                76.005
# ..                         ...                                   ...
# 224                    267.495                                92.490
# 225                    149.226                                58.616
# 226                      3.820                                 3.067
# 227                     50.671                                46.546
# 228                     84.928                                44.021
#
#      PERSONS_FULLY_VACCINATED  PERSONS_FULLY_VACCINATED_PER100  \
# 0                  10386823.0                           26.682
# 1                   1265900.0                           44.481
# 2                   6481186.0                           14.780
# 3                     41423.0                           75.046
# 4                     53482.0                           70.208
# ..                        ...                              ...
# 224                84393196.0                           86.701
# 225                    6989.0                           62.147
# 226                  669393.0                            2.244
# 227                 6354938.0                           34.568
# 228                 4902925.0                           32.988
#
#                                          VACCINES_USED FIRST_VACCINE_DATE  \
# 0    AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...         2021-02-22
# 1    AstraZeneca - Vaxzevria,Gamaleya - Gam-Covid-V...         2021-01-13
# 2    Beijing CNBG - BBIBP-CorV,Gamaleya - Gam-Covid...         2021-01-30
# 3    Janssen - Ad26.COV 2-S,Moderna - Spikevax,Pfiz...         2020-12-21
# 4    AstraZeneca - Vaxzevria,Moderna - Spikevax,Pfi...         2021-01-20
# ..                                                 ...                ...
# 224  AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...         2021-03-08
# 225                                 Moderna - Spikevax         2021-03-19
# 226  AstraZeneca - Vaxzevria,Beijing CNBG - BBIBP-C...         2021-04-20
# 227  Beijing CNBG - BBIBP-CorV,Janssen - Ad26.COV 2...         2021-04-14
# 228  Beijing CNBG - BBIBP-CorV,Bharat - Covaxin,Gam...         2021-02-18
#
#      NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0                          11.0                       NaN
# 1                           5.0                  363122.0
# 2                           4.0                  575651.0
# 3                           3.0                   24160.0
# 4                           3.0                   42940.0
# ..                          ...                       ...
# 224                         6.0                55949328.0
# 225                         1.0                    3201.0
# 226                        11.0                   54985.0
# 227                         3.0                  724977.0
# 228                         4.0                 1177045.0
#
#      PERSONS_BOOSTER_ADD_DOSE_PER100
# 0                                NaN
# 1                             12.759
# 2                              1.313
# 3                             43.770
# 4                             56.369
# ..                               ...
# 224                           57.479
# 225                           28.463
# 226                            0.184
# 227                            3.944
# 228                            7.919
#
# [229 rows x 16 columns]

# %% [markdown]
# - 국가별 개인 건강상태 지표
#
# : 몇 가지 feature들만 발췌하여 분석에 사용될 예정

# %%
with pd.ExcelFile("data/whs2022.xlsx") as xls:
    df_whs1 = pd.read_excel(xls, "Annex 2-1")
    df_whs2 = pd.read_excel(xls, "Annex 2-2")
    df_whs3 = pd.read_excel(xls, "Annex 2-3")
    df_whs4 = pd.read_excel(xls, "Annex 2-4")
    
df_whs1
# Out:
#                        Unnamed: 0                Unnamed: 1 Unnamed: 2  \
# 0                             NaN  Total populationa (000s)        NaN
# 1                       Data type      Comparable estimates        NaN
# 2                             NaN                      Male     Female
# 3                    Member State                      2020        NaN
# 4                     Afghanistan                     19976      18952
# ..                            ...                       ...        ...
# 203               European Region                    452591     480297
# 204  Eastern Mediterranean Region                    374719     351002
# 205        Western Pacific Region                    987323     952556
# 206                           NaN                       NaN        NaN
# 207                        Global                   3911812    3846346
#
#      Unnamed: 3                         Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0           NaN  Life expectancy at birthb (years)        NaN         NaN
# 1           NaN               Comparable estimates        NaN         NaN
# 2    Both sexes                               Male     Female  Both sexes
# 3           NaN                               2019        NaN         NaN
# 4         38928                               63.3       63.2        63.2
# ..          ...                                ...        ...         ...
# 203      932888                               75.1       81.3        78.2
# 204      725721                               68.3       71.3        69.7
# 205     1939879                               74.8       80.8        77.7
# 206         NaN                                NaN        NaN         NaN
# 207     7758157                               70.8       75.9        73.3
#
#                                     Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0    Healthy life expectancy at birthb (years)        NaN         NaN  ...
# 1                         Comparable estimates        NaN         NaN  ...
# 2                                         Male     Female  Both sexes  ...
# 3                                         2019        NaN         NaN  ...
# 4                                         54.7       53.2        53.9  ...
# ..                                         ...        ...         ...  ...
# 203                                       66.6         70        68.3  ...
# 204                                       60.2       60.7        60.4  ...
# 205                                         67       70.2        68.6  ...
# 206                                        NaN        NaN         NaN  ...
# 207                                       62.5       64.9        63.7  ...
#
#     Unnamed: 12                                                3.2  \
# 0           NaN  Under-five mortality ratee (per 1000 live births)
# 1           NaN                               Comparable estimates
# 2           NaN                                                NaN
# 3           NaN                                               2020
# 4           NaN                                                 58
# ..          ...                                                ...
# 203         NaN                                                  8
# 204         NaN                                                 45
# 205         NaN                                                 11
# 206         NaN                                                NaN
# 207         NaN                                                 37
#
#                                          Unnamed: 14  \
# 0    Neonatal mortality ratee (per 1000 live births)
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                                 35
# ..                                               ...
# 203                                                4
# 204                                               25
# 205                                                5
# 206                                              NaN
# 207                                               17
#
#                                                    3.3  \
# 0    New HIV infectionsf (per 1000 uninfected popul...
# 1                                 Comparable estimates
# 2                                                  NaN
# 3                                                 2020
# 4                                                 0.04
# ..                                                 ...
# 203                                               0.18
# 204                                               0.06
# 205                                               0.06
# 206                                                NaN
# 207                                               0.19
#
#                                           Unnamed: 16  \
# 0    Tuberculosis incidenceg (per 100 000 population)
# 1                                Comparable estimates
# 2                                                 NaN
# 3                                                2020
# 4                                                 193
# ..                                                ...
# 203                                                25
# 204                                               112
# 205                                                93
# 206                                               NaN
# 207                                               127
#
#                                           Unnamed: 17 Unnamed: 18  \
# 0    Malaria incidenceh (per 1000 population at risk)         NaN
# 1                                Comparable estimates         NaN
# 2                                                 NaN         NaN
# 3                                                2020         NaN
# 4                                                 8.4         NaN
# ..                                                ...         ...
# 203                                                 0         NaN
# 204                                              11.2         NaN
# 205                                               2.2         NaN
# 206                                               NaN         NaN
# 207                                                59         NaN
#
#                                            Unnamed: 19  \
# 0    Hepatitis B surface antigen (HBsAg) prevalence...
# 1                                 Comparable estimates
# 2                                                  NaN
# 3                                                 2020
# 4                                                 0.39
# ..                                                 ...
# 203                                               0.26
# 204                                               0.84
# 205                                                0.3
# 206                                                NaN
# 207                                               0.94
#
#                                            Unnamed: 20  \
# 0    Reported number of people requiring interventi...
# 1                                         Primary data
# 2                                                  NaN
# 3                                                 2020
# 4                                             14367281
# ..                                                 ...
# 203                                            6639094
# 204                                           75059501
# 205                                           72876938
# 206                                                NaN
# 207                                         1733624366
#
#                       Unnamed: 21
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                    Member State
# 4                     Afghanistan
# ..                            ...
# 203               European Region
# 204  Eastern Mediterranean Region
# 205        Western Pacific Region
# 206                           NaN
# 207                        Global
#
# [208 rows x 22 columns]

# %% [markdown]
# - 국가별 의료 종사자 비율
#
# : 국가 이름 영어/ISO3 형식으로 변환 필요

# %%
df_heal = pd.read_csv('data/how_many_healers.csv')
df_heal.head()
# Out:
#     국가별     2019  2019.1 2019.2  2019.3 2019.4  2019.5   2019.6  2019.7  \
# 0   국가별       의사  #NAME?     약사  #NAME?   치과의사  #NAME?      간호사  #NAME?
# 1   아시아      NaN     NaN    NaN     NaN    NaN     NaN      NaN     NaN
# 2  대한민국   127258    2.46  38941    0.75  26486    0.51   410694    7.93
# 3    중국  3210515    2.24    NaN     NaN    NaN     NaN  4445047     3.1
# 4    인도  1234205     0.9    NaN     NaN    NaN     NaN      NaN     NaN
#
#       2020  ...   2020.6  2020.7 2021  2021.1 2021.2  2021.3 2021.4  2021.5  \
# 0       의사  ...      간호사  #NAME?   의사  #NAME?     약사  #NAME?   치과의사  #NAME?
# 1      NaN  ...      NaN     NaN  NaN     NaN    NaN     NaN    NaN     NaN
# 2   130014  ...   433993    8.37  NaN     NaN    NaN     NaN    NaN     NaN
# 3  3401672  ...  4708717    3.27  NaN     NaN    NaN     NaN    NaN     NaN
# 4      NaN  ...      NaN     NaN  NaN     NaN    NaN     NaN    NaN     NaN
#
#   2021.6  2021.7
# 0    간호사  #NAME?
# 1    NaN     NaN
# 2    NaN     NaN
# 3    NaN     NaN
# 4    NaN     NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# - 국가별 1인당 담배 소비량
#
# : 국가 이름 영어/ISO3 형식으로 변환 필요

# %%
df_smkr = pd.read_csv('data/how_many_smokers.csv')
df_smkr.head()
# Out:
#     국가별    2017    2018    2019    2020 2021
# 0   아시아     NaN     NaN     NaN     NaN  NaN
# 1  대한민국    1607    1606    1574    1592    -
# 2  이스라엘     773     769     727     806  808
# 3    일본    1310    1171    1065     892    -
# 4  튀르키예  1073.7  1178.2  1179.5  1182.4    -

# %% [markdown]
# - 국가별 1인당 알코올 음료 소비량
#
# : 국가 이름 영어/ISO3 형식으로 변환 필요

# %%
df_alc = pd.read_csv('data/how_many_alcohol.csv')
df_alc.head()
# Out:
#      국가별  2017  2018  2019  2020  2021
# 0    아시아   NaN   NaN   NaN   NaN   NaN
# 1   대한민국   8.7   8.5   8.3   7.9   NaN
# 2     중국   5.3   4.8   4.5   NaN   NaN
# 3     인도   2.9   3.0   3.1   NaN   NaN
# 4  인도네시아   0.1   0.1   0.1   NaN   NaN

# %% [markdown]
# ## 참고문헌
#
# - `총, 균, 쇠` / 제레드 다이아몬드
# - `인수공통 모든 전염병의 열쇠` / 데이비드 콰먼
# - `10퍼센트 인간` / 엘리나 콜렌
# - `World health statistics 2022: monitoring health for the SDGs, sustainable development goals` / WHO https://www.who.int/publications/i/item/9789240051157
